# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !gdown 1x36rpsAjtoPrx_r_rTC8_iInkR7vCKrn
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1x36rpsAjtoPrx_r_rTC8_iInkR7vCKrn
# To: /content/student-por.csv
# 100% 93.2k/93.2k [00:00<00:00, 81.2MB/s]

# %%
df = pd.read_csv("student-por.csv")

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (649, 33)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.school.unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
sns.countplot(x='school', data=df, palette='viridis')
# Out:
# <ipython-input-10-f6560d9108d4>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='school', data=df, palette='viridis')
# <Axes: xlabel='school', ylabel='count'>

# %%
sns.histplot(df.age, kde=True, color='salmon')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.address.unique() #Urban=U,Rural=R
# Out:
# array(['U', 'R'], dtype=object)

# %%
sns.countplot(x='address', data=df, palette='dark')
# Out:
# <ipython-input-19-2b6c3cde163f>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='address', data=df, palette='dark')
# <Axes: xlabel='address', ylabel='count'>

# %%
reason_counts=df.reason.value_counts()
reason_counts
# Out:
# course        285
# home          149
# reputation    143
# other          72
# Name: reason, dtype: int64

# %%
plt.pie(reason_counts, labels=reason_counts.index, autopct="%1.1f%%")
plt.show()

# %%
df['activities'].value_counts()
# Out:
# no     334
# yes    315
# Name: activities, dtype: int64

# %%
#pie-chart from above activities in home chart

# %%
df["Walc"].value_counts()
# Out:
# 1    247
# 2    150
# 3    120
# 4     87
# 5     45
# Name: Walc, dtype: int64

# %%
sns.boxplot(df.freetime)
# Out:
# <Axes: ylabel='freetime'>

# %%
sns.histplot(df.studytime)
# Out:
# <Axes: xlabel='studytime', ylabel='Count'>

# %%
df.absences
# Out:
# 0      4
# 1      2
# 2      6
# 3      0
# 4      0
#       ..
# 644    4
# 645    4
# 646    6
# 647    6
# 648    4
# Name: absences, Length: 649, dtype: int64

# %%
df.Pstatus.unique() #Away=A, Together=T
# Out:
# array(['A', 'T'], dtype=object)

# %%
sns.boxplot(data=df, x='Pstatus', y='absences')
# Out:
# <Axes: xlabel='Pstatus', ylabel='absences'>

# %%
df.sex.value_counts()
# Out:
# F    383
# M    266
# Name: sex, dtype: int64

# %%
counts = df.Fjob.value_counts()
counts.plot(kind="bar")
# Out:
# <Axes: >

# %%
counts1 = df.Mjob.value_counts()
counts1.plot(kind="bar")
# Out:
# <Axes: >

# %%
df.hist(bins=100, figsize=(30,40), color='blue')
plt.show()

# %%
df.G1.describe()
# Out:
# count    649.000000
# mean      11.399076
# std        2.745265
# min        0.000000
# 25%       10.000000
# 50%       11.000000
# 75%       13.000000
# max       19.000000
# Name: G1, dtype: float64

# %%
df.G1.value_counts()
# Out:
# 10    95
# 11    91
# 12    82
# 13    72
# 14    71
# 9     65
# 8     42
# 15    35
# 7     33
# 16    22
# 17    16
# 6      9
# 18     7
# 5      5
# 4      2
# 0      1
# 19     1
# Name: G1, dtype: int64

# %%
#make a bar chart

# %%
#bi-variate analysis
sns.countplot(df, x='age',hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.pairplot(df)
plt.show()

# %%
corr=df.corr()
corr
# Out:
# <ipython-input-53-7d5195e2bf4d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.107832 -0.121050    0.034490  -0.008415  0.319968
# Medu       -0.107832  1.000000  0.647477   -0.265079   0.097006 -0.172210
# Fedu       -0.121050  0.647477  1.000000   -0.208288   0.050400 -0.165915
# traveltime  0.034490 -0.265079 -0.208288    1.000000  -0.063154  0.097730
# studytime  -0.008415  0.097006  0.050400   -0.063154   1.000000 -0.147441
# failures    0.319968 -0.172210 -0.165915    0.097730  -0.147441  1.000000
# famrel     -0.020559  0.024421  0.020256   -0.009521  -0.004127 -0.062645
# freetime   -0.004910 -0.019686  0.006841    0.000937  -0.068829  0.108995
# ...

# %%
df.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
#do urban students score higher than rural students
sns.kdeplot(df.loc[df['address']== "U", "G1"], label="Urban", shade=True)
sns.kdeplot(df.loc[df['address']== "R", "G1"], label="Rural", shade=True)
plt.title("Performance of students based on address")
plt.legend()
plt.show()
# Out:
# <ipython-input-58-1c3f938767b1>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[df['address']== "U", "G1"], label="Urban", shade=True)
# <ipython-input-58-1c3f938767b1>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.loc[df['address']== "R", "G1"], label="Rural", shade=True)
