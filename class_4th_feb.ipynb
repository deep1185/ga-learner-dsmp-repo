# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object'].index # columns with object type data
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
dfo = df[df.columns[df.dtypes == 'object']] #dataset with object type columns data
dfo.head()
# Out:
#                                                 Name     Sex  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171   NaN        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282   NaN        S
# 3            113803  C123        S
# 4            373450   NaN        S

# %%
dfo.describe() #the stats for object type data is like this
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
dfn = df[df.columns[df.dtypes != 'object']] # dataset having columns with data types int or float
dfn.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500

# %%
df.describe(include = 'object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.describe(include = 'all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
df.astype('object').describe()
# Out:
#         PassengerId  Survived  Pclass                     Name   Sex    Age  \
# count           891       891     891                      891   891  714.0
# unique          891         2       3                      891     2   88.0
# top               1         0       3  Braund, Mr. Owen Harris  male   24.0
# freq              1       549     491                        1   577   30.0
#
#         SibSp  Parch  Ticket    Fare    Cabin Embarked
# count     891    891     891  891.00      204      889
# unique      7      7     681  248.00      147        3
# top         0      0  347082    8.05  B96 B98        S
# freq      608    678       7   43.00        4      644

# %%
df[10:100:2] #alternate rows 10 to 100, excluding 100
# Out:
#     PassengerId  Survived  Pclass  \
# 10           11         1       3
# 12           13         0       3
# 14           15         0       3
# 16           17         0       3
# 18           19         0       3
# 20           21         0       2
# 22           23         1       3
# 24           25         0       3
# 26           27         0       3
# 28           29         1       3
# 30           31         0       1
# 32           33         1       3
# 34           35         0       1
# 36           37         1       3
# 38           39         0       3
# 40           41         0       3
# 42           43         0       3
# 44           45         1       3
# 46           47         0       3
# 48           49         0       3
# 50           51         0       3
# 52           53         1       1
# 54           55         0       1
# 56           57         1       2
# 58           59         1       2
# 60           61         0       3
# ...

# %%
df['family'] = df['SibSp'] + df['Parch']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  family
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0
# 3      0            113803  53.1000  C123        S       1
# ...

# %%
df['Pclass'].nunique()
# Out:
# 3

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Cabin'].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
# Howmany passengers were less than 5 years old

df[df['Age'] < 5]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 63            64         0       3                     Skoog, Master. Harald
# 78            79         1       2             Caldwell, Master. Alden Gates
# 119          120         0       3         Andersson, Miss. Ellis Anna Maria
# 164          165         0       3              Panula, Master. Eino Viljami
# 171          172         0       3                      Rice, Master. Arthur
# 172          173         1       3              Johnson, Miss. Eleanor Ileen
# 183          184         1       2                 Becker, Master. Richard F
# ...

# %%
len(df[df['Age'] < 5]) #answer
# Out:
# 40

# %%
#How many passengers you can serve alchohol (>18)
len(df[df['Age'] < 18])
# Out:
# 113

# %%
#How many passenger are less than 18 years old
len(df[df['Age'] <= 18])
#len(df) - len(df[df['Age'] > 18])
# Out:
# 139

# %%
#How many passengers have paid below avg fare
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
len(df[ df['Fare']<df['Fare'].mean()])
# Out:
# 680

# %%
list(df[df['Fare'] == 0]['Name'])
# Out:
# ['Leonard, Mr. Lionel',
#  'Harrison, Mr. William',
#  'Tornquist, Mr. William Henry',
#  'Parkes, Mr. Francis "Frank"',
#  'Johnson, Mr. William Cahoone Jr',
#  'Cunningham, Mr. Alfred Fleming',
#  'Campbell, Mr. William',
#  'Frost, Mr. Anthony Wood "Archie"',
#  'Johnson, Mr. Alfred',
#  'Parr, Mr. William Henry Marsh',
#  'Watson, Mr. Ennis Hastings',
#  'Knight, Mr. Robert J',
#  'Andrews, Mr. Thomas Jr',
#  'Fry, Mr. Richard',
#  'Reuchlin, Jonkheer. John George']

# %%
len(df[df['Sex'] == "female"])
# Out:
# 314

# %%
df['Sex'].value_counts(normalize=True) #% of male and female, normally value counts gives counts otherwise
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
len(df[df['Survived']==1]) # How many passengers survived
# Out:
# 342

# %%
df['Survived'].value_counts(normalize=True) #% of passengers survived
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
#How many females paid more than avg fare
len(df[df['Sex'] == "female"])
# Out:
# 314

# %%
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
df[(df['Sex'] == "female") & (df['Fare']>df['Fare'].mean())]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df['Sex'] == "male") | (df['Fare']>df['Fare'].mean())] #
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Fare'] == max(df['Fare'])]['Name'] ## Which passengers paid max fair
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
#How many passengers have Parch greater than 3
#How many passengers who survived have paid maximum fare
#How many passengers who didn't survive was from class 1
#How many passengers having children less than 5 years old

# %%
#access df rows 0-100, alternate rows
df[0:100:2]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 2             3         1       3
# 4             5         0       3
# 6             7         0       1
# 8             9         1       3
# 10           11         1       3
# 12           13         0       3
# 14           15         0       3
# 16           17         0       3
# 18           19         0       3
# 20           21         0       2
# 22           23         1       3
# 24           25         0       3
# 26           27         0       3
# 28           29         1       3
# 30           31         0       1
# 32           33         1       3
# 34           35         0       1
# 36           37         1       3
# 38           39         0       3
# 40           41         0       3
# 42           43         0       3
# 44           45         1       3
# 46           47         0       3
# 48           49         0       3
# 50           51         0       3
# ...

# %%
df.iloc[0:2] #start from zero and go to 1 (explicit index)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  family
# 0      0  A/5 21171   7.2500   NaN        S       1
# 1      0   PC 17599  71.2833   C85        C       1

# %%
df.loc[0:2] #gives rows whose names are 0,1,2 (implicit index/named index)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  family
# 0      0         A/5 21171   7.2500   NaN        S       1
# 1      0          PC 17599  71.2833   C85        C       1
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0

# %%
# iloc gives inbuilt index and loc gives named index

# %%
df.iloc[0:2, ['Name','Age','Sex']] #iloc only accepts numeric index
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-27c3b104f4dc> in <cell line: 1>()
# ----> 1 df.iloc[0:2, ['Name','Age','Sex']] #iloc only accepts numeric index
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1561     def _getitem_tuple(self, tup: tuple):
#    1562
# -> 1563         tup = self._validate_tuple_indexer(tup)
#    1564         with suppress(IndexingError):
#    1565             return self._getitem_lowerdim(tup)
#
# ...

# %%
df.loc[0:2, ['Name','Age','Sex']]
# Out:
#                                                 Name   Age     Sex
# 0                            Braund, Mr. Owen Harris  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                             Heikkinen, Miss. Laina  26.0  female

# %%
df.iloc[0:2, 3:6] #iloc goes only with column nos of those cols
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0

# %%
df['Name'][2:14] #
# Out:
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# Name: Name, dtype: object

# %%
len(df['Name'][2:14])
# Out:
# 12

# %%
s= pd.Series(list(df['Name'][2:5]), index = ['a', 'b', 'c'])
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s1= pd.Series(list(df['Name'][5:8]), index = ['a', 'b', 'c'])
s1
# Out:
# a                  Moran, Mr. James
# b           McCarthy, Mr. Timothy J
# c    Palsson, Master. Gosta Leonard
# dtype: object

# %%
s+s1 #series or dataframe doesn't work with '+' only string can, so it simply jumbles up adding string wise
# Out:
# a               Heikkinen, Miss. LainaMoran, Mr. James
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)Mc...
# c    Allen, Mr. William HenryPalsson, Master. Gosta...
# dtype: object

# %%
s.append(s1) #to concatenate , pd.Concat can also be used
# Out:
# <ipython-input-52-bd1ebd309212>:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s.append(s1) #to concatenate , pd.Concat can also be used
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# a                                Moran, Mr. James
# b                         McCarthy, Mr. Timothy J
# c                  Palsson, Master. Gosta Leonard
# dtype: object

# %%
df.drop('PassengerId' , axis=1) # to drop this column temporarily, to do permanent we hv to put'inplace = True'
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('PassengerId' , axis=1, inplace=True)
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df.drop(1, inplace=True)
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df.set_index('Name', inplace=True) # useful in timeseries data problems, where datetime is in rows
df
# Out:
#                                               Survived  Pclass     Sex   Age  \
# Name
# Braund, Mr. Owen Harris                              0       3    male  22.0
# Heikkinen, Miss. Laina                               1       3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female  35.0
# Allen, Mr. William Henry                             0       3    male  35.0
# Moran, Mr. James                                     0       3    male   NaN
# ...                                                ...     ...     ...   ...
# Montvila, Rev. Juozas                                0       2    male  27.0
# Graham, Miss. Margaret Edith                         1       1  female  19.0
# Johnston, Miss. Catherine Helen "Carrie"             0       3  female   NaN
# Behr, Mr. Karl Howell                                1       1    male  26.0
# Dooley, Mr. Patrick                                  0       3    male  32.0
#
# ...

# %%
df.loc['Allen, Mr. William Henry'] #since loc accesses names
# Out:
# Survived         0
# Pclass           3
# Sex           male
# Age           35.0
# SibSp            0
# Parch            0
# Ticket      373450
# Fare          8.05
# Cabin          NaN
# Embarked         S
# family           0
# Name: Allen, Mr. William Henry, dtype: object

# %%
df.iloc[3] #still it retains inbuilt indexes
# Out:
# Survived         0
# Pclass           3
# Sex           male
# Age           35.0
# SibSp            0
# Parch            0
# Ticket      373450
# Fare          8.05
# Cabin          NaN
# Embarked         S
# family           0
# Name: Allen, Mr. William Henry, dtype: object

# %%
df.reset_index(inplace = True) #reset indices to prior
df
# Out:
#                                              Name  Survived  Pclass     Sex  \
# 0                         Braund, Mr. Owen Harris         0       3    male
# 1                          Heikkinen, Miss. Laina         1       3  female
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1  female
# 3                        Allen, Mr. William Henry         0       3    male
# 4                                Moran, Mr. James         0       3    male
# ..                                            ...       ...     ...     ...
# 885                         Montvila, Rev. Juozas         0       2    male
# 886                  Graham, Miss. Margaret Edith         1       1  female
# 887      Johnston, Miss. Catherine Helen "Carrie"         0       3  female
# 888                         Behr, Mr. Karl Howell         1       1    male
# 889                           Dooley, Mr. Patrick         0       3    male
#
# ...

# %%
d = {"key1":[2,3,4,5],
     "key2":[4,5,6,7],
     "key3":[2,3,4,5]}

# %%
d1 =pd.Series(d)
d1
# Out:
# key1    [2, 3, 4, 5]
# key2    [4, 5, 6, 7]
# key3    [2, 3, 4, 5]
# dtype: object

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     2     4     2
# 1     3     5     3
# 2     4     6     4
# 3     5     7     5

# %%
pwd
# Out:
# '/content'

# %%
df1 = pd.read_csv("/taxonomy.csv.xls")
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.isnull().sum() #how many null values
# Out:
# taxonomy_id     0
# name            0
# parent_id      11
# parent_name    11
# dtype: int64

# %%
df1.dropna() #drops nan values row wise
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis = 1) #drops column wise nan values
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1[['name']].dropna(axis=1)
# Out:
#                              name
# 0                       Emergency
# 1               Disaster Response
# 2                  Emergency Cash
# 3               Help Pay for Food
# 4         Help Pay for Healthcare
# ..                            ...
# 285              Workplace Rights
# 286                     Mediation
# 287                        Notary
# 288                Representation
# 289  Translation & Interpretation
#
# [290 rows x 1 columns]

# %%
df1.fillna("missingvalue", inplace=True)
df1
# Out:
#     taxonomy_id                          name     parent_id  \
# 0           101                     Emergency  missingvalue
# 1        101-01             Disaster Response           101
# 2        101-02                Emergency Cash           101
# 3     101-02-01             Help Pay for Food        101-02
# 4     101-02-02       Help Pay for Healthcare        101-02
# ..          ...                           ...           ...
# 285   111-01-07              Workplace Rights        111-01
# 286      111-02                     Mediation           111
# 287      111-03                        Notary           111
# 288      111-04                Representation           111
# 289      111-05  Translation & Interpretation           111
#
#               parent_name
# 0            missingvalue
# 1               Emergency
# 2               Emergency
# 3          Emergency Cash
# 4          Emergency Cash
# ..                    ...
# 285  Advocacy & Legal Aid
# ...

# %%
#what is average fair paid by people who survived (titanic dataset)

# %%
df.groupby('Survived').mean() #got all stats for people who survived and who didn't
# Out:
# <ipython-input-77-3c64ad474ca2>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').mean() #got all stats for people who survived and who didn't
#             Pclass        Age     SibSp     Parch       Fare    family
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887  0.883424
# 1         1.953079  28.310277  0.472141  0.466276  48.328288  0.938416

# %%
df.groupby(df[df['Survived']==1]).max #got max values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-e442fea304fa> in <cell line: 1>()
# ----> 1 df.groupby(df[df['Survived']==1]).max #got max values
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8400         axis = self._get_axis_number(axis)
#    8401
# -> 8402         return DataFrameGroupBy(
#    8403             obj=self,
#    8404             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     963             from pandas.core.groupby.grouper import get_grouper
#     964
# --> 965             grouper, exclusions, obj = get_grouper(
#     966                 obj,
# ...

# %%
df.groupby('Survived').describe()
# Out:
#          Pclass                                                 Age  \
#           count      mean       std  min  25%  50%  75%  max  count
# Survived
# 0         549.0  2.531876  0.735805  1.0  2.0  3.0  3.0  3.0  424.0
# 1         341.0  1.953079  0.863047  1.0  1.0  2.0  3.0  3.0  289.0
#
#                      ...  Fare           family                                \
#                mean  ...   75%       max  count      mean       std  min  25%
# Survived             ...
# 0         30.626179  ...  26.0  263.0000  549.0  0.883424  1.830669  0.0  0.0
# 1         28.310277  ...  57.0  512.3292  341.0  0.938416  1.187814  0.0  0.0
#
#
#           50%  75%   max
# Survived
# 0         0.0  1.0  10.0
# 1         1.0  2.0   6.0
#
# [2 rows x 48 columns]

# %%
import numpy as np
df.groupby('Survived').aggregate([min, 'max', 'mean', 'median', 'count', np.std, 'var'])
# Out:
# <ipython-input-80-9e320049fbcb>:2: FutureWarning: ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.groupby('Survived').aggregate([min, 'max', 'mean', 'median', 'count', np.std, 'var'])
#          Pclass                                                  Age        \
#             min max      mean median count       std       var   min   max
# Survived
# 0             1   3  2.531876    3.0   549  0.735805  0.541409  1.00  74.0
# 1             1   3  1.953079    2.0   341  0.863047  0.744851  0.42  80.0
#
#                      ...  Fare                         family                \
#                mean  ... count        std          var    min max      mean
# Survived             ...
# 0         30.626179  ...   549  31.388207   985.219509      0  10  0.883424
# ...

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum() #no. of people in survived/not survived column for each sex, plclass
# Out:
# Sex     Pclass
# female  1         90
#         2         70
#         3         72
# male    1         45
#         2         17
#         3         47
# Name: Survived, dtype: int64

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().to_frame()
# Out:
#                Survived
# Sex    Pclass
# female 1             90
#        2             70
#        3             72
# male   1             45
#        2             17
#        3             47

# %%
df.groupby(['Sex', 'Pclass'])['Survived'].sum().to_frame().unstack()
# Out:
#        Survived
# Pclass        1   2   3
# Sex
# female       90  70  72
# male         45  17  47

# %%
import pandas as pd
import numpy as np

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

data = pd.read_json(url)
data.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
#Request method for Json data
import requests
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
data1 = requests.get(url)

# %%
data1
# Out:
# <Response [200]>

# %%
dfj = data1.json()
dfj
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57789',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57789/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57789/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57789/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57789',
#   'id': 2177091933,
#   'node_id': 'PR_kwDOAA0YD85pI21M',
#   'number': 57789,
#   'title': 'Small refactoring',
#   'user': {'login': 'tqa236',
#    'id': 25203655,
#    'node_id': 'MDQ6VXNlcjI1MjAzNjU1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25203655?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tqa236',
#    'html_url': 'https://github.com/tqa236',
#    'followers_url': 'https://api.github.com/users/tqa236/followers',
# ...

# %%
len(dfj)
# Out:
# 30

# %%
for i in range(len(dfj)):
    print(dfj[i])
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57789', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57789/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57789/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57789/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57789', 'id': 2177091933, 'node_id': 'PR_kwDOAA0YD85pI21M', 'number': 57789, 'title': 'Small refactoring', 'user': {'login': 'tqa236', 'id': 25203655, 'node_id': 'MDQ6VXNlcjI1MjAzNjU1', 'avatar_url': 'https://avatars.githubusercontent.com/u/25203655?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tqa236', 'html_url': 'https://github.com/tqa236', 'followers_url': 'https://api.github.com/users/tqa236/followers', 'following_url': 'https://api.github.com/users/tqa236/following{/other_user}', 'gists_url': 'https://api.github.c
# ...

# %%
for i in range(len(dfj)):
    print(dfj[i]['user'])
# Out:
# {'login': 'tqa236', 'id': 25203655, 'node_id': 'MDQ6VXNlcjI1MjAzNjU1', 'avatar_url': 'https://avatars.githubusercontent.com/u/25203655?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/tqa236', 'html_url': 'https://github.com/tqa236', 'followers_url': 'https://api.github.com/users/tqa236/followers', 'following_url': 'https://api.github.com/users/tqa236/following{/other_user}', 'gists_url': 'https://api.github.com/users/tqa236/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/tqa236/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/tqa236/subscriptions', 'organizations_url': 'https://api.github.com/users/tqa236/orgs', 'repos_url': 'https://api.github.com/users/tqa236/repos', 'events_url': 'https://api.github.com/users/tqa236/events{/privacy}', 'received_events_url': 'https://api.github.com/users/tqa236/received_events', 'type': 'User', 'site_admin': False}
# ...

# %%
for i in range(len(dfj)):
    print(dfj[i]['user']['node_id']) #nested dictionary
# Out:
# MDQ6VXNlcjI1MjAzNjU1
# MDQ6VXNlcjQ1NTYyNDAy
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjI1MjAzNjU1
# MDQ6VXNlcjE5NDAxMTMz
# MDQ6VXNlcjI1MjAzNjU1
# MDQ6VXNlcjEwNzEyMTA5
# MDQ6VXNlcjE1NTY5OTU=
# MDQ6VXNlcjYwNjA5ODc5
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjI1OTQzMTg=
# MDQ6VXNlcjMzNDkxNjMy
# MDQ6VXNlcjMzNDkxNjMy
# MDQ6VXNlcjMzNDkxNjMy
# MDQ6VXNlcjkxMTYwNDc1
# MDQ6VXNlcjMzNDkxNjMy
# MDQ6VXNlcjgwNzg5Njg=
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjQ2ODkwMzE1
# MDQ6VXNlcjgyODQ5MjI=
# MDQ6VXNlcjgyODc4MTE1
# MDQ6VXNlcjEwMjA0OTY=
# MDQ6VXNlcjQ1NTYyNDAy
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjI1NzQwNzk=
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjEyNjgzNzU=
# MDQ6VXNlcjgzOTQ3NjY=

# %%
dfjson = pd.DataFrame(dfj)
dfjson.head()
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...
#
# ...

# %%
dfj1 = pd.DataFrame(dfj, columns = ['user', 'timeline_url'])
dfj1.head()
# Out:
#                                                 user  \
# 0  {'login': 'tqa236', 'id': 25203655, 'node_id':...
# 1  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 2  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 3  {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 4  {'login': 'tqa236', 'id': 25203655, 'node_id':...
#
#                                         timeline_url
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# 3  https://api.github.com/repos/pandas-dev/pandas...
# 4  https://api.github.com/repos/pandas-dev/pandas...

# %%
dfj1.to_csv('json_info.csv')
