# %%
#matplotlib, seaborn >>important from interview, plotly >> interactive, bokeh

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#plt.style.use('classic')\
#http://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html

# %%
x = np.random.rand(50)
y = np.random.rand(50)

# %%
x
# Out:
# array([0.92486214, 0.49698796, 0.30530705, 0.32085158, 0.77563782,
#        0.5751322 , 0.60339031, 0.10855312, 0.09617087, 0.87160724,
#        0.16304833, 0.410947  , 0.55248874, 0.95434207, 0.75154705,
#        0.76740436, 0.32671088, 0.2388194 , 0.89535085, 0.66559487,
#        0.89255522, 0.40790063, 0.46595899, 0.73249305, 0.02311314,
#        0.75895128, 0.61177228, 0.49737015, 0.50032784, 0.17189507,
#        0.91626785, 0.84868126, 0.49102734, 0.01925354, 0.2781876 ,
#        0.08342167, 0.53408145, 0.55567333, 0.34384982, 0.65924954,
#        0.3677696 , 0.47416944, 0.66100659, 0.80152417, 0.03646219,
#        0.39075106, 0.9218222 , 0.53468704, 0.08906201, 0.67473241])

# %%
y
# Out:
# array([0.21403511, 0.5721482 , 0.61258378, 0.6869154 , 0.75001442,
#        0.10367528, 0.74152436, 0.56931467, 0.70928668, 0.66261807,
#        0.069737  , 0.74316406, 0.6786815 , 0.6289946 , 0.80505609,
#        0.94345364, 0.08137278, 0.61597762, 0.28676923, 0.57395597,
#        0.74021093, 0.36596507, 0.51759625, 0.77750622, 0.08033882,
#        0.06928201, 0.72590157, 0.54077805, 0.90757177, 0.04710251,
#        0.24903031, 0.54314787, 0.54505831, 0.21938699, 0.51151883,
#        0.30139689, 0.85744608, 0.22806713, 0.03851626, 0.15675443,
#        0.64627366, 0.01647316, 0.21205592, 0.5274322 , 0.02912255,
#        0.58483978, 0.43206158, 0.6280472 , 0.43756415, 0.32615287])

# %%
plt.scatter(x,y)

# %%
df = pd.DataFrame(np.random.randn(1000), columns = ['data'], index = pd.date_range('2020/04/21', periods = 1000))

# %%
df
# Out:
#                 data
# 2020-04-21  0.248530
# 2020-04-22  0.896972
# 2020-04-23  0.294388
# 2020-04-24 -0.605898
# 2020-04-25 -0.080036
# ...              ...
# 2023-01-11 -0.425799
# 2023-01-12 -0.090552
# 2023-01-13 -0.545684
# 2023-01-14  0.002837
# 2023-01-15 -0.519332
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20, 8))
# Out:
# <Axes: >

# %%
x = np.linspace(0, 10, 100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x), '-')

# %%
plt.plot(x, np.sin(x), '--')

# %%
plt.plot(x, np.sin(x), '.-')

# %%
plt.plot(x, np.sin(x), ':')

# %%
plt.figure()
plt.subplot(1, 2, 1)
plt.plot(x, np.sin(x))


plt.subplot(1, 2, 2)
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure()
plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))


plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x))


plt.subplot(2, 2, 3)
plt.plot(x, np.tan(x))

plt.subplot(2, 2, 4)
plt.plot(x, np.cos(x+1))
plt.show()

# %%
plt.figure()
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))


plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.plot(x, np.sin(x-1), color = 'g')
plt.plot(x, np.sin(x-2), color = (1.0, 0.5, 0)) #rgb

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.grid()
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.grid()
plt.title("This is sin plot before real dataset execution to understand basic syntax")
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.grid()
plt.title("This is sin plot before real dataset execution to understand basic syntax")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.axis('equal')
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue', label = 'Sinx')
plt.plot(x, np.cos(x-0), color = 'red', label = 'Cosx')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.grid()
plt.title("This is sin plot before real dataset execution to understand basic syntax")
plt.xlabel("x axis")
plt.ylabel("y axis")
# plt.axis('equal')
plt.legend()
plt.show()

# %%
#Histogram

data = np.random.randn(1000) #10 bins
plt.hist(data, bins = 20, color ='green')
plt.show()

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
y
# Out:
# array([0.21403511, 0.5721482 , 0.61258378, 0.6869154 , 0.75001442,
#        0.10367528, 0.74152436, 0.56931467, 0.70928668, 0.66261807,
#        0.069737  , 0.74316406, 0.6786815 , 0.6289946 , 0.80505609,
#        0.94345364, 0.08137278, 0.61597762, 0.28676923, 0.57395597,
#        0.74021093, 0.36596507, 0.51759625, 0.77750622, 0.08033882,
#        0.06928201, 0.72590157, 0.54077805, 0.90757177, 0.04710251,
#        0.24903031, 0.54314787, 0.54505831, 0.21938699, 0.51151883,
#        0.30139689, 0.85744608, 0.22806713, 0.03851626, 0.15675443,
#        0.64627366, 0.01647316, 0.21205592, 0.5274322 , 0.02912255,
#        0.58483978, 0.43206158, 0.6280472 , 0.43756415, 0.32615287])

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.figure(figsize = (6, 2))
plt.scatter(x, y, c = 'r', alpha = .9, marker = "X" )
plt.xlabel("x")
plt.ylabel("y")
plt.title("scatter plot")
plt.show()

# %%
x
# Out:
# array([0.21341878, 0.77890447, 0.51333179, 0.43090684, 0.30812401,
#        0.9547868 , 0.94614033, 0.42122918, 0.4104607 , 0.66027839,
#        0.39397227, 0.84793362, 0.75683359, 0.98831756, 0.99784292,
#        0.73908521, 0.63857044, 0.92273939, 0.29710078, 0.05957576,
#        0.84802967, 0.07835025, 0.35005717, 0.17011575, 0.09059442,
#        0.92154683, 0.70283785, 0.24788621, 0.82822336, 0.53458199,
#        0.08115197, 0.44494759, 0.25316293, 0.02328123, 0.14313683,
#        0.77625409, 0.71445098, 0.42786119, 0.08309368, 0.07721816,
#        0.85206861, 0.76057067, 0.01519647, 0.02234996, 0.15765105,
#        0.29190922, 0.39681989, 0.20857933, 0.23830386, 0.95937092])

# %%
y
# Out:
# array([0.89031172, 0.17635305, 0.60337247, 0.18626536, 0.5581764 ,
#        0.18697582, 0.66594564, 0.24271742, 0.13628753, 0.742102  ,
#        0.48555395, 0.62045343, 0.91193501, 0.99882765, 0.56457163,
#        0.20046803, 0.57166047, 0.79862486, 0.91492172, 0.58001399,
#        0.02185067, 0.87923991, 0.15286386, 0.71010195, 0.91340389,
#        0.99886154, 0.56689609, 0.89705524, 0.67660399, 0.15107845,
#        0.91785724, 0.45784426, 0.88476887, 0.85985287, 0.60330443,
#        0.78700743, 0.4293318 , 0.78059407, 0.64264069, 0.98581504,
#        0.53337858, 0.0290228 , 0.14783288, 0.19874807, 0.67443771,
#        0.22971024, 0.28437384, 0.93412843, 0.87254146, 0.83796103])

# %%
x=["a", "b", "c", "d"]
y=[4, 6, 1, 2]

# %%
x
# Out:
# ['a', 'b', 'c', 'd']

# %%
y
# Out:
# [4, 6, 1, 2]

# %%
plt.figure(figsize = (6, 3))
plt.bar(x, y, color = '#FF5733')
plt.title("This is my bar plot")
# Out:
# Text(0.5, 1.0, 'This is my bar plot')

# %%
plt.figure(figsize = (6, 3))
plt.barh(x, y, color = '#FF5733')
plt.title("This is my bar plot")
# Out:
# Text(0.5, 1.0, 'This is my bar plot')

# %%
data = [1, 2, 3, 3, 3, 3, 4, 5, 6, 7, 8]
plt.hist(data)
# Out:
# (array([1., 1., 4., 0., 1., 1., 0., 1., 1., 1.]),
#  array([1. , 1.7, 2.4, 3.1, 3.8, 4.5, 5.2, 5.9, 6.6, 7.3, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
#pie chart

langs = ['C', 'Python', 'Java']
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = '%1.1f%%')
plt.title("Pie chart")
plt.show()

# %%
my_explode = (0.0, 0.1, 0.1)

langs = ['C', 'Python', 'Java']
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = '%1.1f%%', explode = my_explode, shadow =  True)
plt.title("Pie chart")
plt.show()

# %%
# 3 d plot

x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x, y, z, c = "#FF5733", alpha = .9)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
x
# Out:
# array([0.44741696, 0.95881027, 0.27730701, 0.09478163, 0.36002616,
#        0.86364401, 0.94033931, 0.1592552 , 0.57524727, 0.95121882,
#        0.67474929, 0.49179329, 0.28212742, 0.16473019, 0.97276275,
#        0.69090862, 0.50976152, 0.03088724, 0.25305732, 0.45644145])

# %%
y
# Out:
# array([0.0867134 , 0.570982  , 0.46212037, 0.16884896, 0.28157404,
#        0.09305157, 0.89935905, 0.80633176, 0.58522034, 0.88143719,
#        0.21448211, 0.38239593, 0.29309401, 0.90032426, 0.91910302,
#        0.0044486 , 0.28689866, 0.89587015, 0.42837946, 0.32769418])

# %%
z
# Out:
# array([0.5438223 , 0.62267368, 0.88091161, 0.46644357, 0.04855704,
#        0.47083651, 0.23887376, 0.92242792, 0.05627197, 0.91271176,
#        0.42813652, 0.05581739, 0.30990777, 0.16437481, 0.14821099,
#        0.14278348, 0.4664283 , 0.10887565, 0.47433273, 0.6562438 ])

# %%
import pandas as pd

data = pd.read_csv("/Bank_churn.csv")
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data.plot.scatter(x = 'Age', y = "Balance")

#insights
#maximum concentration >> 25-50
#maximum >>  40
#min>>0, it is present in all of the age group
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
#Age distribution
plt.title("Age dist")
plt.hist(data["Age"], color = "red")
plt.show()


plt.title("Balance dist")
plt.hist(data["Balance"], color = "red")
plt.show()

# %%
data.boxplot(column = 'Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7fe607aaab90>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7fe607aaa320>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7fe607aaa620>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7fe607aab640>}

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(tips["total_bill"])
# Out:
# <ipython-input-59-02c1a6e7a548>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips["total_bill"], kde = False, bins = 30)
# Out:
# <ipython-input-60-84bee39a7e20>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"], kde = False, bins = 30)
# <Axes: xlabel='total_bill'>

# %%
sns.scatterplot(x = tips.total_bill, y=tips.tip, data = tips, hue= 'smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = tips.total_bill, y=tips.tip, data = tips, hue = 'smoker')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x = tips.total_bill, y=tips.tip, data = tips, hue = 'size')

# %%
sns.relplot(x = tips.total_bill, y=tips.tip, data = tips, style = 'smoker', hue = 'time')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x = tips.total_bill, y=tips.tip)

# %%
sns.jointplot(x = tips.total_bill, y=tips.tip, data = tips, kind="reg")

# %%
sns.jointplot(x = tips.total_bill, y=tips.tip, data = tips, kind="hex")

# %%
sns.jointplot(x = tips.total_bill, y=tips.tip, data = tips, kind="kde") #contour>>meterological

# %%
#pairplot>> it will plot all the pairwise relationship of the dataframe

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue = 'smoker',)

# %%
sns.pairplot(tips, hue = 'smoker',palette = 'coolwarm')

# https://seaborn.pydata.org/generated/seaborn.color_palette.html
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
#Boxplot >> to know outliers
#1, 2, 3, 4, 5, 100 >>> extreme data, for each day give me outlier for total bill

sns.boxplot(x = 'day', y='total_bill', data=tips, palette = 'rainbow')
# Out:
# <ipython-input-79-3c0cececa337>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x = 'day', y='total_bill', data=tips, palette = 'rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips, palette = 'rainbow', orient = 'h')
# Out:
# <Axes: >

# %%
#correlation >> to understand the relationship between

# %%
tips_num = tips[['total_bill', 'tip', 'size']]

# %%
tips_num.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips_num.corr(), annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %%
sns.countplot(x = 'sex', data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x = 'total_bill', y='tip', data = tips, height = 20, aspect = 1)

# %%
sns.catplot(x = 'day', y = 'tip', data = tips, kind='swarm')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
